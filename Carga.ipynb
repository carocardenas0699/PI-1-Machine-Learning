# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import json as js
import ast as ast
import re

# %%
games = pd.read_json('output_steam_games.json',lines=True)

# %%
list_rev = []
archivo1 = r'australian_user_reviews.json'
with open(archivo1, encoding='utf-8') as file:
    for line in file.readlines():
        list_rev.append(ast.literal_eval(line))

reviews = pd.DataFrame(list_rev)
reviews = reviews.explode('reviews')

# %%
list_items = []
archivo2 = r'australian_users_items.json'
with open(archivo2, encoding='utf-8') as file2:
    for line2 in file2.readlines():
        list_items.append(ast.literal_eval(line2))

items = pd.DataFrame(list_items)
items = items.explode('items')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %%
games.tail(20)
# Out:
#                  publisher                                             genres  \
# 120425  Spiderweb Software                             [Strategy, RPG, Indie]
# 120426    Epic Games, Inc.                                           [Action]
# 120427               Valve                                           [Action]
# 120428                None                                               None
# 120429                None                                               None
# 120430                None                                               None
# 120431                None                                               None
# 120432           Fred Ells                                            [Indie]
# 120433             VersoVR  [Casual, Indie, Simulation, Sports, Early Access]
# 120434        Phil Fortier                                 [Adventure, Indie]
# 120435  Retro Army Limited                         [Action, Adventure, Indie]
# ...

# %%
reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
items
# Out:
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88309  edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# ...

# %%
games.isnull().sum()
# Out:
# publisher       8052
# genres          3283
# app_name           2
# title           2050
# release_date    2067
# tags             163
# specs            670
# price           1377
# early_access       0
# id                 2
# developer       3299
# dtype: int64

# %%
items.isnull().sum()
# Out:
# user_id            0
# items_count        0
# steam_id           0
# user_url           0
# items          16806
# dtype: int64

# %%
reviews.isnull().sum()
# Out:
# user_id      0
# user_url     0
# reviews     28
# dtype: int64

# %%
items.drop(columns=['user_url'],inplace=True)

# %%
reviews.drop(columns=['user_url'],inplace=True)

# %% [markdown]
# 120444 registros de games antes de borrar duplicados. Son 88309 registros duplicados y vacios. 3135 registros

# %%
games.drop(games[games.duplicated(subset=['publisher', 'app_name', 'title', 'url', 'release_date', 'reviews_url', 'price', 'early_access', 'id',
       'developer'],keep=False)].index,inplace=True)

# %%
games.drop(columns=['url','reviews_url'],inplace=True)

# %%
games['early_access'].value_counts()
# Out:
# early_access
# 0.0    30188
# 1.0     1947
# Name: count, dtype: int64
